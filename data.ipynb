# %%
# %cd C:\Users\winst\OneDrive\Desktop\data
# Out:
# C:\Users\winst\OneDrive\Desktop\data

# %%
# %pwd
# Out:
# 'C:\\Users\\winst\\OneDrive\\Desktop\\data'

# %%
import pandas as pd
import numpy as np
import math
import json

 

# read in the json files
portfolio = pd.read_json('portfolio.json', orient='records', lines=True)
profile = pd.read_json('profile.json', orient='records', lines=True)
transcript = pd.read_json('transcript.json', orient='records', lines=True)

# %%
profile.head(10)
# Out:
#   gender  age                                id  became_member_on    income
# 0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2   None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4   None  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
# 5      M   68  e2127556f4f64592b11af22de27a7932          20180426   70000.0
# 6   None  118  8ec6ce2a7e7949b1bf142def7d0e0586          20170925       NaN
# 7   None  118  68617ca6246f4fbc85e91a2a49552598          20171002       NaN
# 8      M   65  389bc3fa690240e798340f5a15918d5c          20180209   53000.0
# 9   None  118  8974fc5686fe429db53ddde067b88302          20161122       NaN

# %%
profile.isnull().sum()
# Out:
# gender              2175
# age                    0
# id                     0
# became_member_on       0
# income              2175
# dtype: int64

# %%
transcript.head(10)
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
# 5  389bc3fa690240e798340f5a15918d5c  offer received
# 6  c4863c7985cf408faee930f111475da3  offer received
# 7  2eeac8d8feae4a8cad5a6af0499a211d  offer received
# 8  aa4862eba776480b8bb9c68455b8c2e1  offer received
# 9  31dda685af34476cad5bc968bdb01c53  offer received
#
#                                               value  time
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0
# 5  {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}     0
# 6  {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}     0
# 7  {'offer id': '3f207df678b143eea3cee63160fa8bed'}     0
# 8  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 9  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0

# %%
transcript.isnull().sum()
# Out:
# person    0
# event     0
# value     0
# time      0
# dtype: int64

# %%
len(transcript)
# Out:
# 306534

# %%
len(profile)
# Out:
# 17000

# %%
len(portfolio)
# Out:
# 10

# %%
portfolio.head(10)
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10         7           bogo
# 1      10  [web, email, mobile, social]          10         5           bogo
# 2       0          [web, email, mobile]           0         4  informational
# 3       5          [web, email, mobile]           5         7           bogo
# 4       5                  [web, email]          20        10       discount
# 5       3  [web, email, mobile, social]           7         7       discount
# 6       2  [web, email, mobile, social]          10        10       discount
# 7       0       [email, mobile, social]           0         3  informational
# 8       5  [web, email, mobile, social]           5         5           bogo
# 9       2          [web, email, mobile]          10         7       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  3f207df678b143eea3cee63160fa8bed
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 6  fafdcd668e3743c1bb461111dcafc2a4
# 7  5a8bc65990b245e5a138643cd4eb9837
# 8  f19421c1d4aa40978ebb69ca19b0e20d
# 9  2906b810c7d4411798c6938adc9daaa5

# %%
portfolio.isnull().sum()
# Out:
# reward        0
# channels      0
# difficulty    0
# duration      0
# offer_type    0
# id            0
# dtype: int64

# %%
#Edit portfolio dataset
#https://stackoverflow.com/questions/18889588/create-dummies-from-column-with-multiple-values-in-pandas
channels = portfolio['channels'].str.join(sep='*').str.get_dummies(sep='*')
offer_type = pd.get_dummies(portfolio["offer_type"])
offer_type

portfolio_new = pd.concat([portfolio, channels, offer_type], axis=1, sort=False)
portfolio_new.drop(['channels', 'offer_type'],axis=1)
col = portfolio_new.pop('id')
portfolio_new.insert(0, 'id', col)
portfolio_new
# Out:
#                                  id  reward                      channels  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd      10       [email, mobile, social]
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0      10  [web, email, mobile, social]
# 2  3f207df678b143eea3cee63160fa8bed       0          [web, email, mobile]
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9       5          [web, email, mobile]
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       5                  [web, email]
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       3  [web, email, mobile, social]
# 6  fafdcd668e3743c1bb461111dcafc2a4       2  [web, email, mobile, social]
# 7  5a8bc65990b245e5a138643cd4eb9837       0       [email, mobile, social]
# 8  f19421c1d4aa40978ebb69ca19b0e20d       5  [web, email, mobile, social]
# 9  2906b810c7d4411798c6938adc9daaa5       2          [web, email, mobile]
#
#    difficulty  duration     offer_type  email  mobile  social  web  bogo  \
# 0          10         7           bogo      1       1       1    0     1
# 1          10         5           bogo      1       1       1    1     1
# 2           0         4  informational      1       1       0    1     0
# 3           5         7           bogo      1       1       0    1     1
# 4          20        10       discount      1       0       0    1     0
# 5           7         7       discount      1       1       1    1     0
# 6          10        10       discount      1       1       1    1     0
# 7           0         3  informational      1       1       1    0     0
# 8           5         5           bogo      1       1       1    1     1
# 9          10         7       discount      1       1       0    1     0
#
#    discount  informational
# 0         0              0
# 1         0              0
# 2         0              1
# 3         0              0
# 4         1              0
# 5         1              0
# 6         1              0
# 7         0              1
# 8         0              0
# 9         1              0

# %%
#Edit profile dataset
profile['age'].unique()
profile[profile['age']==118]

#Remove rows where age is 118 since it is unrealistic and missing gender values

profile_new = profile.drop(profile[profile['age']==118].index)
profile_new.isnull().sum()
#profile_new
# Out:
#       gender  age                                id  became_member_on  \
# 1          F   55  0610b486422d4921ae7d2bf64640c50b          20170715
# 3          F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509
# 5          M   68  e2127556f4f64592b11af22de27a7932          20180426
# 8          M   65  389bc3fa690240e798340f5a15918d5c          20180209
# 12         M   58  2eeac8d8feae4a8cad5a6af0499a211d          20171111
# ...      ...  ...                               ...               ...
# 16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7          20180604
# 16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77          20180713
# 16997      M   49  01d26f638c274aa0b965d24cefe3183f          20170126
# 16998      F   83  9dc1421481194dcd9400aec7c9ae6366          20160307
# 16999      F   62  e4052622e5ba45a8b96b59aba68cf068          20170722
#
#          income
# 1      112000.0
# 3      100000.0
# 5       70000.0
# 8       53000.0
# 12      51000.0
# ...         ...
# 16995   54000.0
# 16996   72000.0
# 16997   73000.0
# 16998   50000.0
# 16999   82000.0
#
# [14825 rows x 5 columns]

# %%
#Edit transcript dataset
#Edit the value column to separate out offer id and amount
#need to append values in loop, right now
#for k in range(1,len(transcript.value)):
#    offer_list = list(transcript.value[k].keys())
#    amount = list(transcript.value[k].values())

#list(transcript.value.keys())
transcript.value.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-16d34f05952b> in <module>
#       7
#       8 #list(transcript.value.keys())
# ----> 9 transcript.value.values()
#
# TypeError: 'numpy.ndarray' object is not callable
